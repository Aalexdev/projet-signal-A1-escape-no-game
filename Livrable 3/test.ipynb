# %% [markdown]
# # Test

# %% [markdown]
# ## Téléchargement et installation des dépendances

# %%
# %pip install numpy
# %pip install sounddevice
# %pip install matplotlib
# Out:
# Requirement already satisfied: numpy in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (2.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sounddevice in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (0.5.1)
# Requirement already satisfied: CFFI>=1.0 in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (from sounddevice) (1.17.1)
# Requirement already satisfied: pycparser in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (from CFFI>=1.0->sounddevice) (2.22)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (from matplotlib) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in /home/alexismagnier/.local/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/alexismagnier/Dev/projet-signal-A1-escape-no-game/.conda/lib/python3.11/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/alexismagnier/.local/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/alexismagnier/.local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importation des libraries

# %%
import numpy as np
import sounddevice as sd
from matplotlib import pyplot as plt

# %%
import program
import commands
import variables

# All the registred commands and their functions


def main():
    while True:
        # Get the user command
        user_input = input().split()

        # Check if user_input is empty
        if not user_input:
            continue
        
        # Checks if the command is registred
        if not user_input[0] in commands.cmds:
            print(f"\"{user_input[0]}\" is not a registred command")
            continue
        
        # Calls the command
        func = commands.cmds.get(user_input[0])

        result = func(user_input[1:])

        if result == commands.Status.EXIT:
            print("EXIT")
            break

        elif result == commands.Status.INVALID_ARGS:
            print(f"Invalid arguments for \"{user_input[0]}\"")
        
        elif result == commands.Status.FAILURE:
            print("FAILURE")

if __name__ == "__main__":
    main()
# Out:
# EXIT
